# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as stats
from matplotlib.ticker import FuncFormatter
pd.set_option('float_format', '{:f}'.format)

# %%
cd ..
# Out:
# /Users/alphonsowoodbury/DS/mod2project/flatiron_mod2_project_kch

# %%
df = pd.read_csv('data/kc_cleaned.csv')
df
# Out:
#               price  bedrooms  bathrooms  sqft_living     sqft_lot  floors  \
# 0     221900.000000         3          1  1180.000000  5650.000000       1
# 1     538000.000000         3          2  2570.000000  7242.000000       2
# 2     180000.000000         2          1   770.000000 10000.000000       1
# 3     604000.000000         4          3  1960.000000  5000.000000       1
# 4     510000.000000         3          2  1680.000000  8080.000000       1
# ...             ...       ...        ...          ...          ...     ...
# 21592 360000.000000         3          2  1530.000000  1131.000000       3
# 21593 400000.000000         4          2  2310.000000  5813.000000       2
# 21594 402101.000000         2          0  1020.000000  1350.000000       2
# 21595 400000.000000         3          2  1600.000000  2388.000000       2
# 21596 325000.000000         2          0  1020.000000  1076.000000       2
#
# ...

# %%
df.describe()
# Out:
#                price     bedrooms    bathrooms  sqft_living       sqft_lot  \
# count   21597.000000 21597.000000 21597.000000 21597.000000   21597.000000
# mean   540296.573506     3.373200     1.750660  2080.321850   15099.408760
# std    367368.140101     0.926299     0.734042   918.106125   41412.636876
# min     78000.000000     1.000000     0.000000   370.000000     520.000000
# 25%    322000.000000     3.000000     1.000000  1430.000000    5040.000000
# 50%    450000.000000     3.000000     2.000000  1910.000000    7618.000000
# 75%    645000.000000     4.000000     2.000000  2550.000000   10685.000000
# max   7700000.000000    33.000000     8.000000 13540.000000 1651359.000000
#
#             floors         view    condition        grade      zipcode  \
# count 21597.000000 21597.000000 21597.000000 21597.000000 21597.000000
# mean      1.445988     0.233181     3.409825     7.657915 98077.951845
# std       0.551658     0.764673     0.650546     1.173200    53.513072
# ...

# %% [markdown]
# ---

# %%
cd Images
# Out:
# /Users/alphonsowoodbury/DS/mod2project/flatiron_mod2_project_kch/Images

# %% [markdown]
# ---

# %% [markdown]
# ## Feature: Zipcode

# %%
palette = ["#9b59b6", "#3498db", "#95a5a6", "#e74c3c", "#34495e", "#2ecc71"]


# def millions(x, pos):
#     'The two args are the value and tick position'
#     return '$%1.1fM' % (x * 1e-7)

# props = dict(boxstyle='round', facecolor='grey', alpha=0.5)
# formatter = FuncFormatter(millions)

fig, ax = plt.subplots(figsize=(15,5))
# ax.yaxis.set_major_formatter(formatter)
# ax.xaxis.set_major_formatter(formatter)

g = sns.boxplot(df.zipcode,df.price,palette=palette)
g.set_xticklabels(labels=df.zipcode,rotation=90)
plt.suptitle('um',fontweight='bold',fontsize=15,x=0.125,ha='left',y=.9,va='baseline')


plt.savefig('zipcode_box.png')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Feature: Condition, age, and grade

# %%
mybins = range(0, df.eff_built.max(), 25)
df['age_bucket'] = pd.cut(df.eff_built, bins=mybins)
df['age_bucket'].value_counts()

def millions(x, pos):
    'The two args are the value and tick position'
    return '$%1.1fM' % (x * 1e-7)

props = dict(boxstyle='round', facecolor='grey', alpha=0.5)
formatter = FuncFormatter(millions)


fig, ax = plt.subplots(figsize=(10,7.5))
ax.yaxis.set_major_formatter(formatter)
ax.xaxis.set_major_formatter(formatter)


f, axes = plt.subplots(1, 3,figsize=(15,5),sharey='row')
fig.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')
plt.subplots_adjust(wspace=0)

sns.violinplot(  y="price", x= "condition", data=df,  orient='v' , ax=axes[0],cut=0,palette=palette)
sns.violinplot(  y="price", x= "grade", data=df,  orient='v' , ax=axes[2],cut=0,palette=palette)
sns.violinplot(x='age_bucket',y='price',data=df,  orient='v',ax=axes[1] ,cut=0,palette=palette)

plt.suptitle('Distribution of home price by condition, grade, relative age',fontweight='bold',fontsize=15,x=0.125,ha='left',y=.9,va='baseline')

plt.savefig('cond_grade_age_violin.png')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## Feature: Amenities (renovation, basement, waterfront)(engineered)

# %%
f, axes = plt.subplots(1, 3,figsize=(15,5),sharey='row')
fig.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')
plt.subplots_adjust(wspace=0)

sns.violinplot(df.has_renovation,df.price, ax=axes[0], cut=0,palette=palette) #ztest
sns.violinplot(df.has_basement,df.price, ax=axes[1], cut=0,palette=palette) #ztest
sns.violinplot(df.has_waterfront,df.price, ax=axes[2], cut=0,palette=palette) #ztest
plt.suptitle('Distribution of home price by engineered amenities',fontweight='bold',fontsize=15,x=0.125,ha='left',y=.9,va='baseline')

plt.savefig('amenities_violin.png')
plt.show()

# %% [markdown]
# ## Feature: Rooms (bed, bath)

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
fig.text(0.04, 0.5, 'common Y', va='center', rotation='vertical')
plt.subplots_adjust(wspace=0)

sns.boxplot(y="price", x= "bedrooms", data=df,  orient='v' , ax=axes[0],palette=flatui)
sns.boxplot(y="price", x= "bathrooms", data=df,  orient='v' , ax=axes[1],palette=flatui)
plt.suptitle('Distribution of home price by number of bedrooms, bathrooms',fontweight='bold',fontsize=15,x=0.125,ha='left',y=.9,va='baseline')

plt.savefig('rooms_box.png')
plt.show()

# %% [markdown]
# ## Feature: View

# %%
plt.figure(figsize=(20,5))
sns.boxplot(df.view,df.price,palette=palette)
plt.suptitle("Distribution of home price by view rating",fontweight='bold',fontsize=15,x=0.125,ha='left',y=.9,va='baseline')

plt.savefig('view_box.png')

# %%
#sns.set()
df = df[df['long'] < -121.8]
df = df[df['lat'] > 47.4]

view = df.view
size = (np.sqrt(df.price**3/(1000000000000000)))
fig, ax = plt.subplots(figsize=(60,60))
ax.set_facecolor('xkcd:navy')


scatter = plt.scatter(df.long,df.lat,c=view,s=size, cmap='Set3',alpha=.7)

legend = ax.legend(*scatter.legend_elements(),
                    loc="lower left", title="View Rating",prop={'size': 36},markerscale=5)
ax.add_artist(legend)
plt.title('View and relative price by latitude and longitude',fontweight='bold',fontsize=30,x=0.005,ha='left',y=1,va='baseline')
ax.set_aspect('equal')
ax.get_xaxis().set_ticks([])
ax.get_yaxis().set_ticks([])

#plt.gcf().subplots_adjust(bottom=0.075,left=0.075,top=0.765,right=1.075)

plt.savefig('views.png')
plt.show()

## for presentation, add map, clean up axis labels

# %%
df1 = df.groupby(['zipcode','yr_sold'],axis=0).mean()
df1 = df1.reset_index()
df1
# Out:
#      zipcode  yr_sold          price  bedrooms  bathrooms  sqft_living  \
# 0      98004     2014 1296414.076190  3.866667   2.109524  2882.857143
# 1      98004     2015 1474496.719626  3.831776   2.084112  2960.373832
# 2      98005     2014  803538.830508  3.830508   2.008475  2677.822034
# 3      98005     2015  826221.740000  3.900000   2.000000  2607.200000
# 4      98006     2014  829632.184438  3.855908   2.077810  2861.135447
# ..       ...      ...            ...       ...        ...          ...
# 118    98188     2015  303355.188679  3.358491   1.547170  1835.849057
# 119    98198     2014  282714.870968  3.129032   1.322581  1728.790323
# 120    98198     2015  260584.146341  3.121951   1.268293  1514.853659
# 121    98199     2014  790693.182243  3.233645   1.808411  2176.355140
# 122    98199     2015  795293.349515  3.165049   1.776699  2131.553398
#
#         sqft_lot   floors     view  condition    grade       lat        long  \
# ...

# %%
view = df1.zipcode
size = (np.sqrt(df1.price**3/(1000000000)))
fig, ax = plt.subplots(figsize=(60,60))
ax.set_facecolor('xkcd:navy')


scatter = plt.scatter(df1.long,df1.lat,c=view,s=size, cmap='Set2',alpha=.7)

# legend = ax.legend(*scatter.legend_elements(),
#                     loc="lower left", title="View Rating")
# ax.add_artist(legend)
plt.title('View and relative price by latitude and longitude',fontweight='bold',fontsize=15,x=0.005,ha='left',y=1,va='baseline')
ax.set_aspect('equal')

#plt.gcf().subplots_adjust(bottom=0.075,left=0.075,top=0.765,right=1.075)

plt.savefig('views.png')
plt.show()

## for presentation, add map, clean up axis labels
