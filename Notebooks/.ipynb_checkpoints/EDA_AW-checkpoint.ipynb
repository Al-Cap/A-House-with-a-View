# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import scipy.stats as stats

# %%
cd ..
# Out:
# /Users/alphonsowoodbury/DS/mod2project/flatiron_mod2_project_kch

# %%
df = pd.read_csv('kc_cleaned.csv')
df
# Out:
#              date     price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      2014-10-13  221900.0         3          1       1180.0    5650.0
# 1      2014-12-09  538000.0         3          2       2570.0    7242.0
# 2      2015-02-25  180000.0         2          1        770.0   10000.0
# 3      2014-12-09  604000.0         4          3       1960.0    5000.0
# 4      2015-02-18  510000.0         3          2       1680.0    8080.0
# ...           ...       ...       ...        ...          ...       ...
# 21592  2014-05-21  360000.0         3          2       1530.0    1131.0
# 21593  2015-02-23  400000.0         4          2       2310.0    5813.0
# 21594  2014-06-23  402101.0         2          0       1020.0    1350.0
# 21595  2015-01-16  400000.0         3          2       1600.0    2388.0
# 21596  2014-10-15  325000.0         2          0       1020.0    1076.0
#
#        floors  waterfront  view  condition  ...  yr_renovated  zipcode  \
# 0           1         NaN     0          3  ...           NaN    98178
# 1           2         NaN     0          3  ...        1991.0    98125
# 2           1         NaN     0          3  ...           NaN    98028
# 3           1         NaN     0          5  ...           NaN    98136
# 4           1         NaN     0          3  ...           NaN    98074
# ...       ...         ...   ...        ...  ...           ...      ...
# 21592       3         NaN     0          3  ...           NaN    98103
# 21593       2         NaN     0          3  ...           NaN    98146
# 21594       2         NaN     0          3  ...           NaN    98144
# 21595       2         NaN     0          3  ...           NaN    98027
# 21596       2         NaN     0          3  ...           NaN    98144
#
#            lat     long  sqft_living15  sqft_lot15  has_waterfront  \
# 0      47.5112 -122.257         1340.0      5650.0               0
# 1      47.7210 -122.319         1690.0      7639.0               0
# 2      47.7379 -122.233         2720.0      8062.0               0
# 3      47.5208 -122.393         1360.0      5000.0               0
# 4      47.6168 -122.045         1800.0      7503.0               0
# ...        ...      ...            ...         ...             ...
# 21592  47.6993 -122.346         1530.0      1509.0               0
# 21593  47.5107 -122.362         1830.0      7200.0               0
# 21594  47.5944 -122.299         1020.0      2007.0               0
# 21595  47.5345 -122.069         1410.0      1287.0               0
# 21596  47.5941 -122.299         1020.0      1357.0               0
#
#        has_basement  has_renovation  eff_built
# 0                 0               0         65
# 1                 1               1         29
# 2                 0               0         87
# 3                 1               0         55
# 4                 0               0         33
# ...             ...             ...        ...
# 21592             0               0         11
# 21593             0               0          6
# 21594             0               0         11
# 21595             0               0         16
# 21596             0               0         12
#
# [21597 rows x 24 columns]

# %%
# df['ppsqft'] = df.price / df.sqft_living
# df

# %%
# import seaborn as sns
# sns.set(style="ticks")

# sns.pairplot(df)
# plt.show()

# %%
# # import `sample` from `random`
# from random import sample

# # Create a random index
# randomIndex = np.array(sample(range(len(df)), 75))

# # Get 5 random rows
# df_sample = df.iloc[randomIndex]

# df_sample

# %%
# df_sample.describe()

# %%
# df_sqft = df_sample[['price','sqft_living','ppsqft']]

# %%
# df_sqft = df_sqft.sort_values(by=['price'], axis=0, ascending=False)
# df_sqft.head(30)

# %%
# sns.boxplot(df.sqft_living,df.ppsqft)

# %%
# Define your own bins
mybins = range(0, df.eff_built.max(), 25)

# Cut the data with the help of the bins
df['age_bucket'] = pd.cut(df.eff_built, bins=mybins)

# Count the number of values per bucket
df['age_bucket'].value_counts()
# Out:
# (0, 25]      6240
# (25, 50]     5938
# (50, 75]     5807
# (75, 100]    2335
# Name: age_bucket, dtype: int64

# %%
plt.figure(figsize=(20,15))
sns.boxplot(df.age_bucket,df.price)

# %%
sns.scatterplot(df.eff_built,df.price)

# %%
df.age_bucket.describe()
# Out:
# count       20320
# unique          4
# top       (0, 25]
# freq         6240
# Name: age_bucket, dtype: object

# %%
plt.hist(df.eff_built)
# Out:
# (array([3878., 2839., 2929., 2532., 3152., 2445., 1251.,  981.,  840.,
#          750.]),
#  array([  5. ,  16.5,  28. ,  39.5,  51. ,  62.5,  74. ,  85.5,  97. ,
#         108.5, 120. ]),
#  <a list of 10 Patch objects>)

# %%
print(df['price'].describe())
plt.figure(figsize=(9, 8))
sns.distplot(df['price'], color='g', bins=100, hist_kws={'alpha': 0.4});

# %%
plt.figure(figsize=(20,15))

sns.boxplot(df.zipcode,df.price)
#f-test?

# %%
f, axes = plt.subplots(1, 2,figsize=(25,5))
#plt.figure(figsize=(15,30))
sns.violinplot(  y="price", x= "condition", data=df,  orient='v' , ax=axes[0])
sns.violinplot(  y="price", x= "grade", data=df,  orient='v' , ax=axes[1])

# %%
f, axes = plt.subplots(1, 3,figsize=(25,5))
#plt.figure(figsize=(15,30))
sns.violinplot(df.has_renovation,df.price, ax=axes[0]) #ztest
sns.violinplot(df.has_basement,df.price, ax=axes[1]) #ztest
sns.violinplot(df.has_waterfront,df.price, ax=axes[2]) #ztest

# %%
f, axes = plt.subplots(1, 2,figsize=(15,5))
#plt.figure(figsize=(15,30))
sns.boxplot(  y="price", x= "bedrooms", data=df,  orient='v' , ax=axes[0])
sns.boxplot(  y="price", x= "bathrooms", data=df,  orient='v' , ax=axes[1])

# %%
f, axes = plt.subplots(1, 4,figsize=(25,5))
#plt.figure(figsize=(15,30))
sns.scatterplot(  y="price", x= "sqft_living", data=df,   ax=axes[0])
sns.scatterplot(  y="price", x= "sqft_living15", data=df, ax=axes[2])
sns.distplot(df.sqft_living,  ax=axes[1])
sns.distplot(df.sqft_living15,ax=axes[3])

# %%
plt.figure(figsize=(20,15))
sns.boxplot(df.view,df.price)
